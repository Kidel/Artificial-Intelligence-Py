# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from simulatedAnnealing import *
from queensPuzzle import *

# %%
QP = QueensPuzzle(size=8)

# %%
SA = SimulatedAnnealing(problem=QP)

# %%
SA.solve()
# Out:
# halted
# [4, 1, 7, 0, 3, 6, 2, 5]

# %%
plot(SA.evaluations)
plot(SA.temps)
grid(1)
xlabel('Iterations')
ylabel('Temperature and Evaluation')

# %%
plot(SA.localMax, 'ro')
grid(1)
