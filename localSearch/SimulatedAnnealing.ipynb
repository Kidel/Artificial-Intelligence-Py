# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from simulatedAnnealing import *
from queensPuzzle import *

# %%
QP = QueensPuzzle(size=14)

# %%
SA = SimulatedAnnealing(problem=QP)

# %%
SA.solve()
# Out:
# halted
# [9, 5, 13, 1, 7, 2, 11, 6, 10, 3, 0, 12, 4, 8]

# %%
plot(SA.evaluations)
plot(SA.temps)
grid(1)
xlabel('Iterations')
ylabel('Temperature (green) | Evaluation (blue)')

# %%
QP.printBoard(SA.localMax)
